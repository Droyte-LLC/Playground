# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import os

# Print the current working directory, help ensure you're able to load dataset from correct path
print("Current Working Directory:", os.getcwd())

# Load the dataset from your csv file
df = pd.read_csv("./StockMarketDataset.csv")

# %%
# Lists all the columns
print(df.columns.tolist())

# Dropping first column as it just mirrors the row number, no meaningful data
df.drop(columns=['Unnamed: 0'], inplace=True)

# Lists all the columns
print(f'Columns after dropping the first column: {df.columns.tolist()}')

# %%
# Checks for missing (null/NaN) values in a DataFrame (df), returns count of null values in each column
# Example: 

#Returns the count of null values in each column
df.isnull().sum()

# %%
df.describe()

# %%
# Parse the date
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True, format="%d-%m-%Y")
df = df.sort_values('Date')  # Ensure chronological order
df.reset_index(drop=True, inplace=True)

# List all columns ending in '_Price'
#print('Printing all columns that have _Price in its name')
price_columns = [col for col in df.columns if col.endswith('_Price')]
#print(price_columns)

# Convert them to numeric (in case they are strings)
for col in price_columns:
    # Ensure all values are strings (safe to apply string ops)
    df[col] = df[col].astype(str)
    
    # Remove commas and convert to numeric (force errors to NaN)
    df[col] = df[col].str.replace(',', '', regex=False)

    #print(f'Before conversion: {df[col]}')
    print(f'After conversion: {pd.to_numeric(df[col], errors='coerce')}')

#print('After converting price columns to numeric')
#print(df.head())

# Now drop or fill any NaNs caused by bad entries
df = df.dropna(subset=price_columns)

# Inspecting data, first few rows, last few rows, if any nulls are still present
print(f'First few rows: {df.head()}')
print(f'Last few rows: {df.tail()}')
print(f'Any nulls still present? {df.isna().sum()}')

# %%
# Convert columns to numeric where possible, coercing errors to NaN
df = df.apply(pd.to_numeric, errors='coerce')

# 1. Compute percent missing per column
missing_pct = df.isna().mean()

# 2. Define threshold (e.g., 5%)
threshold = 0.05

# 3. Identify low- and high-missing columns
cols_impute = missing_pct[missing_pct < threshold].index.tolist()
cols_drop = missing_pct[missing_pct >= threshold].index.tolist()
print(f'Columns to drop (≥{threshold*100}% missing): {cols_drop}')

# 4. Impute median for those columns
medians = {col: df[col].median() for col in cols_impute}
df[cols_impute] = df[cols_impute].fillna(medians)

# 5. Drop high-missing columns
df = df.drop(columns=cols_drop)

# Display the cleaned DataFrame
print("Cleaned DataFrame:")
print(df)

# %%
print(f'Any nulls still present? {df.isna().sum()}')

# %%
# Get all columns that represent asset prices (end in '_Price')
price_columns = [col for col in df.columns if col.endswith('_Price')]

# Calculate daily percentage returns
returns = df[price_columns].pct_change()

# Rolling volatility calculations
volatility_7 = returns.rolling(window=7).std()
volatility_14 = returns.rolling(window=14).std()
volatility_21 = returns.rolling(window=21).std()

# Rename columns
volatility_7.columns = [f'{col}_vol_7d' for col in volatility_7.columns]
volatility_14.columns = [f'{col}_vol_14d' for col in volatility_14.columns]
volatility_21.columns = [f'{col}_vol_21d' for col in volatility_21.columns]

# %%
# Merge back to the original df
df = pd.concat([df, volatility_7, volatility_14, volatility_21], axis=1)
df = df.dropna()  # Drop rows with NaNs introduced by rolling windows

# %%
#df[['Date', 'Bitcoin_Price', 'Bitcoin_Price_vol_7d', 'Bitcoin_Price_vol_14d', 'Bitcoin_Price_vol_21d']].head()
print(df)

# %%
# Reset index example
print('''Code example:\n pd.DataFrame({ 
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35]
    }, index=['a', 'b', 'c'])''')

df = pd.DataFrame({ 
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35]
    }, index=['a', 'b', 'c'])

print('\nNow we remove \'Bob\' with:\n df = df[df[\'Age\'] != 30]') 
df = df[df['Age'] != 30]

print(f'If we don\'t reset index, we get:\n {df}')
df.reset_index(drop=True, inplace=True)
print(f'After we reset index, we get:\n {df}')

# %%
## 1. Load csv file
# Import necessary libraries
import pandas as pd
import numpy as np
import os

# For debugging, help ensure you're able to load dataset from correct path
print("Current Working Directory:", os.getcwd())

# Load the dataset from your csv file
df = pd.read_csv("./StockMarketDataset.csv")

## 2. Sanitize dataset
# The first column is used for the row number, unnecessary, dropping it
df.drop(columns=['Unnamed: 0'], inplace=True)

# Parse and sort dates in chronological order
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True, format="%d-%m-%Y")
df = df.sort_values('Date')  # Ensure chronological order
df.reset_index(drop=True, inplace=True)

# Removing commas from price columns and convert to numeric
price_columns = [col for col in df.columns if col.endswith('_Price')]

for col in price_columns:
    # Ensure all values are strings (safe to apply string ops)
    df[col] = df[col].astype(str)
    
    # Remove commas and convert to numeric (force errors to NaN)
    df[col] = df[col].str.replace(',', '', regex=False)

df = df.apply(pd.to_numeric, errors='coerce')

## 3. Impute missing data with mean and drop
# Compute percent missing per column
missing_pct = df.isna().mean()

# Define threshold (e.g., 5%)
threshold = 0.05

# Identify low-missing and high-missing columns
cols_impute = missing_pct[missing_pct < threshold].index.tolist()
cols_drop = missing_pct[missing_pct >= threshold].index.tolist()

# Impute median on low missing columns
medians = {col: df[col].median() for col in cols_impute}
df[cols_impute] = df[cols_impute].fillna(medians)

# Drop high-missing columns
df = df.drop(columns=cols_drop)

## 4. Calculate rolling volatility
# Calculate daily percentage returns
returns = df[price_columns].pct_change()

# Rolling volatility calculations
volatility_7 = returns.rolling(window=7).std()
volatility_14 = returns.rolling(window=14).std()
volatility_21 = returns.rolling(window=21).std()

# Rename columns
volatility_7.columns = [f'{col}_vol_7d' for col in volatility_7.columns]
volatility_14.columns = [f'{col}_vol_14d' for col in volatility_14.columns]
volatility_21.columns = [f'{col}_vol_21d' for col in volatility_21.columns]

df = pd.concat([df, volatility_7, volatility_14, volatility_21], axis=1)
df = df.dropna()  # Drop rows with NaNs introduced by rolling windows

## Save cleaned up dataset!
print("Cleaned dataset:")
print(df)
df.to_csv('StockMarketDataset_Sanitized.csv', index=False)
# Out:
# Current Working Directory: /Users/gjbaptiste/Dev/Repos/Playground/Python
# Cleaned dataset:
#                      Date  Natural_Gas_Price  Natural_Gas_Vol.  \
# 21    1551830400000000000              2.841          119630.0
# 22    1551916800000000000              2.866          117000.0
# 23    1552003200000000000              2.865           85880.0
# 24    1552262400000000000              2.772          136890.0
# 25    1552348800000000000              2.784           90020.0
# ...                   ...                ...               ...
# 1238  1706486400000000000              2.490            3590.0
# 1239  1706572800000000000              2.077          139750.0
# 1240  1706659200000000000              2.100          142860.0
# 1241  1706745600000000000              2.050          161340.0
# 1242  1706832000000000000              2.079          127370.0
#
#       Crude_oil_Price  Crude_oil_Vol.  Copper_Price  Copper_Vol.  \
# 21              56.22        637680.0        2.9185      51450.0
# 22              56.66        628820.0        2.9105      59930.0
# 23              56.07        747360.0        2.8935      66540.0
# 24              56.79        597160.0        2.9010      43180.0
# 25              56.87        652800.0        2.9285      68210.0
# ...               ...             ...           ...          ...
# 1238            76.78        331930.0        3.8790      10180.0
# 1239            77.82        347240.0        3.9110      10180.0
# 1240            75.85        344490.0        3.9060      10180.0
# 1241            73.82        577940.0        3.8535      10180.0
# 1242            72.28        366885.0        3.8215      10180.0
#
#       Bitcoin_Price  Bitcoin_Vol.  Platinum_Price  ...  Tesla_Price_vol_21d  \
# 21           3863.0     2520000.0          829.70  ...             0.028099
# 22           3875.1     2600000.0          816.50  ...             0.027162
# 23           3865.9     2960000.0          818.85  ...             0.028101
# 24           3870.3     3190000.0          820.65  ...             0.028108
# 25           3886.0     2900000.0          835.90  ...             0.028570
# ...             ...           ...             ...  ...                  ...
# 1238        43299.8       45230.0          938.30  ...             0.030789
# 1239        42946.2       55130.0          931.70  ...             0.030759
# 1240        42580.5       56480.0          932.60  ...             0.030807
# 1241        43081.4       47690.0          922.30  ...             0.031041
# 1242        43194.7       42650.0          901.60  ...             0.030417
#
#       Microsoft_Price_vol_21d  Silver_Price_vol_21d  Google_Price_vol_21d  \
# 21                   0.008714              0.010193              0.011335
# 22                   0.008883              0.010193              0.011528
# 23                   0.008409              0.011240              0.009987
# 24                   0.009091              0.011263              0.010588
# 25                   0.009126              0.011379              0.010801
# ...                       ...                   ...                   ...
# 1238                 0.008313              0.013984              0.010893
# 1239                 0.008456              0.014002              0.011511
# 1240                 0.010838              0.013729              0.020678
# 1241                 0.010495              0.013760              0.020568
# 1242                 0.010879              0.012389              0.020613
#
#       Nvidia_Price_vol_21d  Berkshire_Price_vol_21d  Netflix_Price_vol_21d  \
# 21                0.017060                 0.009591               0.015645
# 22                0.017545                 0.009670               0.016036
# 23                0.017068                 0.009624               0.015989
# 24                0.021116                 0.009291               0.016243
# 25                0.021135                 0.009176               0.016297
# ...                    ...                      ...                    ...
# 1238              0.020199                 0.007851               0.027709
# 1239              0.020143                 0.008001               0.028416
# 1240              0.021154                 0.008475               0.028250
# 1241              0.019458                 0.008188               0.026300
# 1242              0.020102                 0.008317               0.026465
#
#       Amazon_Price_vol_21d  Meta_Price_vol_21d  Gold_Price_vol_21d
# 21                0.012138            0.012969            0.006743
# 22                0.012996            0.013484            0.006738
# 23                0.012793            0.013478            0.007155
# 24                0.013987            0.012660            0.007265
# 25                0.013370            0.012636            0.007340
# ...                    ...                 ...                 ...
# 1238              0.012411            0.014093            0.006873
# 1239              0.012918            0.014173            0.007145
# 1240              0.013898            0.015185            0.007297
# 1241              0.014521            0.013984            0.007307
# 1242              0.021692            0.044970            0.006779
#
# [1222 rows x 94 columns]

# %%
# Finalized Version, Sanitized and Labeled for Machine Learning training

import pandas as pd
import numpy as np
import os

# 1. Load CSV file
print("Current Directory:", os.getcwd())
df = pd.read_csv("./StockMarketDataset.csv")

# 2. Sanitize dataset
df.drop(columns=['Unnamed: 0'], inplace=True)
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True, format="%d-%m-%Y")
df = df.sort_values('Date').reset_index(drop=True)

price_cols = [c for c in df.columns if c.endswith('_Price')]
for col in price_cols:
    df[col] = df[col].astype(str).str.replace(',', '', regex=False)
df = df.apply(pd.to_numeric, errors='coerce')

# 3. Impute missing & drop high-missing
missing_pct = df.isna().mean()
threshold = 0.05
cols_impute = [c for c in df if missing_pct[c] < threshold]
cols_drop = [c for c in df if missing_pct[c] >= threshold]
df[cols_impute] = df[cols_impute].fillna(df[cols_impute].median())
df.drop(columns=cols_drop, inplace=True)

# 4. Compute rolling volatilities
returns = df[price_cols].pct_change()
vol_7 = returns.rolling(7).std().add_suffix('_vol_7d')
vol_14 = returns.rolling(14).std().add_suffix('_vol_14d')
vol_21 = returns.rolling(21).std().add_suffix('_vol_21d')

df = pd.concat([df, vol_7, vol_14, vol_21], axis=1).dropna().reset_index(drop=True)

# 5. Quantile-based labeling per asset & window
for window in ['7d', '14d', '21d']:
    vol_cols = [c for c in df.columns if c.endswith(f'_vol_{window}')]
    for col in vol_cols:
        q_low, q_high = df[col].quantile([0.33, 0.66])
        label_col = f'{col}_Risk'
        df[label_col] = df[col].apply(
            lambda v: 'Low' if v <= q_low else 'Medium' if v <= q_high else 'High'
        )
        print(f"{label_col}: ≤{q_low:.4f} Low; ≤{q_high:.4f} Med; else High")

# 6. One-hot encode all Risk label columns
risk_cols = [c for c in df.columns if c.endswith('_Risk')]
df = pd.concat([df, pd.get_dummies(df[risk_cols], prefix=risk_cols)], axis=1)

# 7. Save final dataset with labels
print("Sample of Risk labels:")
print(df[risk_cols].head())
print(df[risk_cols].tail())
df.to_csv('StockMarketDataset_Sanitized_Labeled.csv', index=False)
# Out:
# Current Directory: /Users/gjbaptiste/Dev/Repos/Playground/Python
# Natural_Gas_Price_vol_7d_Risk: ≤0.0268 Low; ≤0.0445 Med; else High
# Crude_oil_Price_vol_7d_Risk: ≤0.0167 Low; ≤0.0252 Med; else High
# Copper_Price_vol_7d_Risk: ≤0.0102 Low; ≤0.0144 Med; else High
# Bitcoin_Price_vol_7d_Risk: ≤0.0259 Low; ≤0.0409 Med; else High
# Platinum_Price_vol_7d_Risk: ≤0.0144 Low; ≤0.0200 Med; else High
# Ethereum_Price_vol_7d_Risk: ≤0.0339 Low; ≤0.0504 Med; else High
# S&P_500_Price_vol_7d_Risk: ≤0.0067 Low; ≤0.0110 Med; else High
# Nasdaq_100_Price_vol_7d_Risk: ≤0.0093 Low; ≤0.0154 Med; else High
# Apple_Price_vol_7d_Risk: ≤0.0125 Low; ≤0.0190 Med; else High
# Tesla_Price_vol_7d_Risk: ≤0.0259 Low; ≤0.0398 Med; else High
# Microsoft_Price_vol_7d_Risk: ≤0.0117 Low; ≤0.0181 Med; else High
# Silver_Price_vol_7d_Risk: ≤0.0130 Low; ≤0.0194 Med; else High
# Google_Price_vol_7d_Risk: ≤0.0124 Low; ≤0.0191 Med; else High
# Nvidia_Price_vol_7d_Risk: ≤0.0215 Low; ≤0.0315 Med; else High
# Berkshire_Price_vol_7d_Risk: ≤0.0079 Low; ≤0.0114 Med; else High
# Netflix_Price_vol_7d_Risk: ≤0.0164 Low; ≤0.0260 Med; else High
# Amazon_Price_vol_7d_Risk: ≤0.0137 Low; ≤0.0211 Med; else High
# Meta_Price_vol_7d_Risk: ≤0.0153 Low; ≤0.0239 Med; else High
# Gold_Price_vol_7d_Risk: ≤0.0068 Low; ≤0.0100 Med; else High
# Natural_Gas_Price_vol_14d_Risk: ≤0.0300 Low; ≤0.0441 Med; else High
# Crude_oil_Price_vol_14d_Risk: ≤0.0180 Low; ≤0.0252 Med; else High
# Copper_Price_vol_14d_Risk: ≤0.0111 Low; ≤0.0144 Med; else High
# Bitcoin_Price_vol_14d_Risk: ≤0.0295 Low; ≤0.0411 Med; else High
# Platinum_Price_vol_14d_Risk: ≤0.0154 Low; ≤0.0203 Med; else High
# Ethereum_Price_vol_14d_Risk: ≤0.0358 Low; ≤0.0523 Med; else High
# S&P_500_Price_vol_14d_Risk: ≤0.0071 Low; ≤0.0113 Med; else High
# Nasdaq_100_Price_vol_14d_Risk: ≤0.0100 Low; ≤0.0154 Med; else High
# Apple_Price_vol_14d_Risk: ≤0.0133 Low; ≤0.0192 Med; else High
# Tesla_Price_vol_14d_Risk: ≤0.0302 Low; ≤0.0403 Med; else High
# Microsoft_Price_vol_14d_Risk: ≤0.0127 Low; ≤0.0184 Med; else High
# Silver_Price_vol_14d_Risk: ≤0.0148 Low; ≤0.0199 Med; else High
# Google_Price_vol_14d_Risk: ≤0.0138 Low; ≤0.0200 Med; else High
# Nvidia_Price_vol_14d_Risk: ≤0.0226 Low; ≤0.0327 Med; else High
# Berkshire_Price_vol_14d_Risk: ≤0.0084 Low; ≤0.0115 Med; else High
# Netflix_Price_vol_14d_Risk: ≤0.0183 Low; ≤0.0278 Med; else High
# Amazon_Price_vol_14d_Risk: ≤0.0149 Low; ≤0.0218 Med; else High
# Meta_Price_vol_14d_Risk: ≤0.0171 Low; ≤0.0246 Med; else High
# Gold_Price_vol_14d_Risk: ≤0.0077 Low; ≤0.0101 Med; else High
# Natural_Gas_Price_vol_21d_Risk: ≤0.0317 Low; ≤0.0450 Med; else High
# Crude_oil_Price_vol_21d_Risk: ≤0.0188 Low; ≤0.0255 Med; else High
# Copper_Price_vol_21d_Risk: ≤0.0114 Low; ≤0.0146 Med; else High
# Bitcoin_Price_vol_21d_Risk: ≤0.0310 Low; ≤0.0429 Med; else High
# Platinum_Price_vol_21d_Risk: ≤0.0161 Low; ≤0.0203 Med; else High
# Ethereum_Price_vol_21d_Risk: ≤0.0383 Low; ≤0.0531 Med; else High
# S&P_500_Price_vol_21d_Risk: ≤0.0074 Low; ≤0.0114 Med; else High
# Nasdaq_100_Price_vol_21d_Risk: ≤0.0104 Low; ≤0.0156 Med; else High
# Apple_Price_vol_21d_Risk: ≤0.0136 Low; ≤0.0198 Med; else High
# Tesla_Price_vol_21d_Risk: ≤0.0304 Low; ≤0.0402 Med; else High
# Microsoft_Price_vol_21d_Risk: ≤0.0133 Low; ≤0.0186 Med; else High
# Silver_Price_vol_21d_Risk: ≤0.0152 Low; ≤0.0196 Med; else High
# Google_Price_vol_21d_Risk: ≤0.0145 Low; ≤0.0204 Med; else High
# Nvidia_Price_vol_21d_Risk: ≤0.0229 Low; ≤0.0340 Med; else High
# Berkshire_Price_vol_21d_Risk: ≤0.0087 Low; ≤0.0115 Med; else High
# Netflix_Price_vol_21d_Risk: ≤0.0190 Low; ≤0.0280 Med; else High
# Amazon_Price_vol_21d_Risk: ≤0.0153 Low; ≤0.0227 Med; else High
# Meta_Price_vol_21d_Risk: ≤0.0179 Low; ≤0.0251 Med; else High
# Gold_Price_vol_21d_Risk: ≤0.0079 Low; ≤0.0100 Med; else High
# Sample of Risk labels:
#   Natural_Gas_Price_vol_7d_Risk Crude_oil_Price_vol_7d_Risk  \
# 0                           Low                         Low
# 1                           Low                         Low
# 2                           Low                         Low
# 3                           Low                         Low
# 4                           Low                         Low
#
#   Copper_Price_vol_7d_Risk Bitcoin_Price_vol_7d_Risk  \
# 0                      Low                       Low
# 1                      Low                       Low
# 2                      Low                       Low
# 3                      Low                       Low
# 4                      Low                       Low
#
#   Platinum_Price_vol_7d_Risk Ethereum_Price_vol_7d_Risk  \
# 0                        Low                     Medium
# 1                        Low                     Medium
# 2                        Low                     Medium
# 3                        Low                     Medium
# 4                        Low                     Medium
#
#   S&P_500_Price_vol_7d_Risk Nasdaq_100_Price_vol_7d_Risk  \
# 0                       Low                          Low
# 1                       Low                          Low
# 2                       Low                          Low
# 3                    Medium                       Medium
# 4                    Medium                       Medium
#
#   Apple_Price_vol_7d_Risk Tesla_Price_vol_7d_Risk  ...  \
# 0                     Low                    High  ...
# 1                     Low                    High  ...
# 2                     Low                  Medium  ...
# 3                  Medium                  Medium  ...
# 4                  Medium                     Low  ...
#
#   Tesla_Price_vol_21d_Risk Microsoft_Price_vol_21d_Risk  \
# 0                      Low                          Low
# 1                      Low                          Low
# 2                      Low                          Low
# 3                      Low                          Low
# 4                      Low                          Low
#
#   Silver_Price_vol_21d_Risk Google_Price_vol_21d_Risk  \
# 0                       Low                       Low
# 1                       Low                       Low
# 2                       Low                       Low
# 3                       Low                       Low
# 4                       Low                       Low
#
#   Nvidia_Price_vol_21d_Risk Berkshire_Price_vol_21d_Risk  \
# 0                       Low                       Medium
# 1                       Low                       Medium
# 2                       Low                       Medium
# 3                       Low                       Medium
# 4                       Low                       Medium
#
#   Netflix_Price_vol_21d_Risk Amazon_Price_vol_21d_Risk  \
# 0                        Low                       Low
# 1                        Low                       Low
# 2                        Low                       Low
# 3                        Low                       Low
# 4                        Low                       Low
#
#   Meta_Price_vol_21d_Risk Gold_Price_vol_21d_Risk
# 0                     Low                     Low
# 1                     Low                     Low
# 2                     Low                     Low
# 3                     Low                     Low
# 4                     Low                     Low
#
# [5 rows x 57 columns]
#      Natural_Gas_Price_vol_7d_Risk Crude_oil_Price_vol_7d_Risk  \
# 1217                          High                      Medium
# 1218                          High                      Medium
# 1219                          High                      Medium
# 1220                          High                      Medium
# 1221                          High                      Medium
#
#      Copper_Price_vol_7d_Risk Bitcoin_Price_vol_7d_Risk  \
# 1217                   Medium                    Medium
# 1218                   Medium                    Medium
# 1219                      Low                       Low
# 1220                   Medium                       Low
# 1221                      Low                       Low
#
#      Platinum_Price_vol_7d_Risk Ethereum_Price_vol_7d_Risk  \
# 1217                     Medium                        Low
# 1218                     Medium                        Low
# 1219                     Medium                        Low
# 1220                     Medium                        Low
# 1221                     Medium                        Low
#
#      S&P_500_Price_vol_7d_Risk Nasdaq_100_Price_vol_7d_Risk  \
# 1217                       Low                          Low
# 1218                       Low                          Low
# 1219                    Medium                       Medium
# 1220                    Medium                       Medium
# 1221                    Medium                       Medium
#
#      Apple_Price_vol_7d_Risk Tesla_Price_vol_7d_Risk  ...  \
# 1217                     Low                    High  ...
# 1218                     Low                    High  ...
# 1219                     Low                    High  ...
# 1220                     Low                    High  ...
# 1221                     Low                    High  ...
#
#      Tesla_Price_vol_21d_Risk Microsoft_Price_vol_21d_Risk  \
# 1217                   Medium                          Low
# 1218                   Medium                          Low
# 1219                   Medium                          Low
# 1220                   Medium                          Low
# 1221                   Medium                          Low
#
#      Silver_Price_vol_21d_Risk Google_Price_vol_21d_Risk  \
# 1217                       Low                       Low
# 1218                       Low                       Low
# 1219                       Low                      High
# 1220                       Low                      High
# 1221                       Low                      High
#
#      Nvidia_Price_vol_21d_Risk Berkshire_Price_vol_21d_Risk  \
# 1217                       Low                          Low
# 1218                       Low                          Low
# 1219                       Low                          Low
# 1220                       Low                          Low
# 1221                       Low                          Low
#
#      Netflix_Price_vol_21d_Risk Amazon_Price_vol_21d_Risk  \
# 1217                     Medium                       Low
# 1218                       High                       Low
# 1219                       High                       Low
# 1220                     Medium                       Low
# 1221                     Medium                    Medium
#
#      Meta_Price_vol_21d_Risk Gold_Price_vol_21d_Risk
# 1217                     Low                     Low
# 1218                     Low                     Low
# 1219                     Low                     Low
# 1220                     Low                     Low
# 1221                    High                     Low
#
# [5 rows x 57 columns]
